# %% [markdown]
# # 💬 Navigate through docs using a chatbot with Argilla and LlamaIndex
#
# In this tutorial, you'll learn about the integration between Argilla and LlamaIndex, by creating a multi-document agent over the Argilla documentation.
#
# This tutorial includes the following steps:
# [TODO]
#
# You can use the `Open in Colab` button at the top of this page, which allows you to run the notebook directly on Google Colab. Don't forget to change the runtime type to GPU for faster model training and inference.

# %% [markdown]
# ## Introduction
#
# Let's start by installing the required dependencies

# %% [markdown]
# ### Downloads

# %%
# !pip install llama-index-agent-openai
# !pip install llama-index-readers-file
# !pip install llama-index-postprocessor-cohere-rerank
# !pip install llama-index-llms-openai
# !pip install llama-index-embeddings-openai
# !pip install unstructured
# !pip install partition_image
# !pip install argilla-llama-index
# !pip install llama-index-callbacks-argilla
# !pip install argilla
# Out:
# Requirement already satisfied: unstructured in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (0.12.4)
# Requirement already satisfied: chardet in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (5.1.0)
# Requirement already satisfied: nltk in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (2.10.1)
# Requirement already satisfied: dataclasses-json in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (0.6.4)
# Requirement already satisfied: python-iso639 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (2024.2.7)
# Requirement already satisfied: langdetect in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (1.23.5)
# Requirement already satisfied: rapidfuzz in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (3.6.1)
# Requirement already satisfied: backoff in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (4.9.0)
# Requirement already satisfied: unstructured-client>=0.15.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (0.18.0)
# Requirement already satisfied: wrapt in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (2024.2.2)
# Requirement already satisfied: charset-normalizer>=3.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (3.3.2)
# Requirement already satisfied: dataclasses-json-speakeasy>=0.5.11 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (0.5.11)
# Requirement already satisfied: idna>=3.4 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (3.6)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (3.20.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (2.8.2)
# Requirement already satisfied: six>=1.16.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (1.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (0.9.0)
# Requirement already satisfied: urllib3>=1.26.18 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (2.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: click in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk->unstructured) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk->unstructured) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk->unstructured) (4.66.2)
# Requirement already satisfied: argilla-llama-index in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (0.0.1a0)
# Requirement already satisfied: argilla>=1.18.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla-llama-index) (1.24.0)
# Requirement already satisfied: llama-index>=0.9.32 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla-llama-index) (0.10.1)
# Requirement already satisfied: packaging>=23.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla-llama-index) (23.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla-llama-index) (4.9.0)
# Requirement already satisfied: httpx<=0.26,>=0.15 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (0.26.0)
# Requirement already satisfied: deprecated~=1.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (1.2.14)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (1.5.3)
# Requirement already satisfied: pydantic>=1.10.7 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (2.6.1)
# Requirement already satisfied: wrapt<1.15,>=1.13 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (1.14.1)
# Requirement already satisfied: numpy<1.24.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (1.23.5)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (4.66.2)
# Requirement already satisfied: backoff in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (2.2.1)
# Requirement already satisfied: monotonic in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (1.6)
# Requirement already satisfied: rich!=13.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (13.7.0)
# Requirement already satisfied: typer<0.10.0,>=0.6.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla>=1.18.0->argilla-llama-index) (0.9.0)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.10.3)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.1)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.1)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.1)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.1)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index>=0.9.32->argilla-llama-index) (0.1.3)
# Requirement already satisfied: anyio in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (4.2.0)
# Requirement already satisfied: certifi in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (1.0.2)
# Requirement already satisfied: idna in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (3.6)
# Requirement already satisfied: sniffio in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (0.14.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (0.6.4)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (2024.2.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.12.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (0.6.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (0.9.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index>=0.9.32->argilla-llama-index) (4.12.3)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index>=0.9.32->argilla-llama-index) (0.0.2)
# Requirement already satisfied: pymupdf<2.0.0,>=1.23.21 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index>=0.9.32->argilla-llama-index) (1.23.22)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index>=0.9.32->argilla-llama-index) (4.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.0.0->argilla>=1.18.0->argilla-llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.0.0->argilla>=1.18.0->argilla-llama-index) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla>=1.18.0->argilla-llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla>=1.18.0->argilla-llama-index) (2.16.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from rich!=13.1.0->argilla>=1.18.0->argilla-llama-index) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from rich!=13.1.0->argilla>=1.18.0->argilla-llama-index) (2.17.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from typer<0.10.0,>=0.6.0->argilla>=1.18.0->argilla-llama-index) (8.1.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.0->llama-index>=0.9.32->argilla-llama-index) (2.5)
# Requirement already satisfied: mdurl~=0.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich!=13.1.0->argilla>=1.18.0->argilla-llama-index) (0.1.2)
# Requirement already satisfied: joblib in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from anyio->httpx<=0.26,>=0.15->argilla>=1.18.0->argilla-llama-index) (1.2.0)
# Requirement already satisfied: PyMuPDFb==1.23.22 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.0->llama-index>=0.9.32->argilla-llama-index) (1.23.22)
# Requirement already satisfied: six>=1.5 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->argilla>=1.18.0->argilla-llama-index) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.0->llama-index>=0.9.32->argilla-llama-index) (3.20.2)
# Requirement already satisfied: llama-index-callbacks-argilla in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: argilla<2.0.0,>=1.22.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-callbacks-argilla) (1.24.0)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-callbacks-argilla) (0.10.3)
# Requirement already satisfied: httpx<=0.26,>=0.15 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (0.26.0)
# Requirement already satisfied: deprecated~=1.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.2.14)
# Requirement already satisfied: packaging>=20.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (23.2)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.5.3)
# Requirement already satisfied: pydantic>=1.10.7 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2.6.1)
# Requirement already satisfied: wrapt<1.15,>=1.13 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.14.1)
# Requirement already satisfied: numpy<1.24.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.23.5)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (4.66.2)
# Requirement already satisfied: backoff in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2.2.1)
# Requirement already satisfied: monotonic in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.6)
# Requirement already satisfied: rich!=13.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (13.7.0)
# Requirement already satisfied: typer<0.10.0,>=0.6.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (0.9.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (3.9.3)
# Requirement already satisfied: dataclasses-json in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (0.6.4)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (2024.2.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.12.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (4.0.3)
# Requirement already satisfied: anyio in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (4.2.0)
# Requirement already satisfied: certifi in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.0.2)
# Requirement already satisfied: idna in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (3.6)
# Requirement already satisfied: sniffio in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (0.14.0)
# Requirement already satisfied: click in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (8.1.7)
# Requirement already satisfied: joblib in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.0.0->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.0.0->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (2.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from rich!=13.1.0->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from rich!=13.1.0->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-callbacks-argilla) (3.20.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from anyio->httpx<=0.26,>=0.15->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich!=13.1.0->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->argilla<2.0.0,>=1.22.0->llama-index-callbacks-argilla) (1.16.0)
# Requirement already satisfied: argilla in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (1.24.0)
# Requirement already satisfied: httpx<=0.26,>=0.15 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (0.26.0)
# Requirement already satisfied: deprecated~=1.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (1.2.14)
# Requirement already satisfied: packaging>=20.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (23.2)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (1.5.3)
# Requirement already satisfied: pydantic>=1.10.7 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (2.6.1)
# Requirement already satisfied: wrapt<1.15,>=1.13 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (1.14.1)
# Requirement already satisfied: numpy<1.24.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (1.23.5)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (4.66.2)
# Requirement already satisfied: backoff in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (2.2.1)
# Requirement already satisfied: monotonic in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (1.6)
# Requirement already satisfied: rich!=13.1.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (13.7.0)
# Requirement already satisfied: typer<0.10.0,>=0.6.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from argilla) (0.9.0)
# Requirement already satisfied: anyio in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla) (4.2.0)
# Requirement already satisfied: certifi in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla) (1.0.2)
# Requirement already satisfied: idna in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla) (3.6)
# Requirement already satisfied: sniffio in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpx<=0.26,>=0.15->argilla) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<=0.26,>=0.15->argilla) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.0.0->argilla) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pandas<2.0.0,>=1.0.0->argilla) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from pydantic>=1.10.7->argilla) (4.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from rich!=13.1.0->argilla) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from rich!=13.1.0->argilla) (2.17.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from typer<0.10.0,>=0.6.0->argilla) (8.1.7)
# Requirement already satisfied: mdurl~=0.1 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich!=13.1.0->argilla) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->argilla) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages (from anyio->httpx<=0.26,>=0.15->argilla) (1.2.0)

# %% [markdown]
# ### Imports

# %%
import os
import nest_asyncio
from pathlib import Path
from tqdm.notebook import tqdm
import pickle

from argilla_llama_index import ArgillaCallbackHandler

from llama_index.core import Document, Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.readers.file import UnstructuredReader
from llama_index.core import set_global_handler

from llama_index.agent.openai import OpenAIAgent
from llama_index.core import (
    load_index_from_storage,
    StorageContext,
    VectorStoreIndex,
)
from llama_index.core import SummaryIndex
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.node_parser import SentenceSplitter
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │    4 from tqdm.notebook import tqdm                                                              │
# │    5 import pickle                                                                               │
# │    6                                                                                             │
# │ ❱  7 from argilla_llama_index import ArgillaCallbackHandler                                      │
# │    8                                                                                             │
# │    9 from llama_index.core import Document, Settings                                             │
# │   10 from llama_index.llms.openai import OpenAI                                                  │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/argilla │
# │ _llama_index/__init__.py:17 in <module>                                                          │
# │                                                                                                  │
# │   14                                                                                             │
# │   15 __version__ = "0.0.1-alpha"                                                                 │
# │   16                                                                                             │
# │ ❱ 17 from argilla_llama_index.llama_index_handler import ArgillaCallbackHandler                  │
# │   18                                                                                             │
# │   19 __all__ = ["ArgillaCallbackHandler"]                                                        │
# │   20                                                                                             │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/argilla │
# │ _llama_index/llama_index_handler.py:11 in <module>                                               │
# │                                                                                                  │
# │     8 from collections import defaultdict                                                        │
# │     9 from contextvars import ContextVar                                                         │
# │    10                                                                                            │
# │ ❱  11 from llama_index.callbacks.base_handler import BaseCallbackHandler                         │
# │    12 from llama_index.callbacks.schema import (                                                 │
# │    13 │   BASE_TRACE_EVENT,                                                                      │
# │    14 │   CBEventType,                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'llama_index.callbacks.base_handler'

# %% [markdown]
# ## Download Data

# %%
domain = "docs.argilla.io"
docs_url = "https://docs.argilla.io/en/latest/"
# !wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains {domain} --no-parent {docs_url}
# Out:
# Both --no-clobber and --convert-links were specified, only --convert-links will be used.
# --2024-02-14 12:43:19--  https://docs.argilla.io/en/latest/
# Resolving docs.argilla.io (docs.argilla.io)... 104.17.33.82, 104.17.32.82
# Connecting to docs.argilla.io (docs.argilla.io)|104.17.33.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/index.html’
#
# docs.argilla.io/en/     [ <=>                ]  73,07K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:19 (62,9 MB/s) - ‘docs.argilla.io/en/latest/index.html’ saved [74827]
#
# --2024-02-14 12:43:19--  https://docs.argilla.io/en/latest/genindex.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/genindex.html’
#
# docs.argilla.io/en/     [ <=>                ] 147,87K  --.-KB/s    in 0,02s
#
# 2024-02-14 12:43:19 (5,82 MB/s) - ‘docs.argilla.io/en/latest/genindex.html’ saved [151418]
#
# --2024-02-14 12:43:19--  https://docs.argilla.io/en/latest/search.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/search.html’
#
# docs.argilla.io/en/     [ <=>                ]  54,82K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:20 (111 MB/s) - ‘docs.argilla.io/en/latest/search.html’ saved [56137]
#
# --2024-02-14 12:43:20--  https://docs.argilla.io/en/latest/getting_started/quickstart.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/quickstart.html’
#
# docs.argilla.io/en/     [ <=>                ]  58,69K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:20 (105 MB/s) - ‘docs.argilla.io/en/latest/getting_started/quickstart.html’ saved [60102]
#
# --2024-02-14 12:43:20--  https://docs.argilla.io/en/latest/_static/favicon.ico
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15086 (15K) [image/vnd.microsoft.icon]
# Saving to: ‘docs.argilla.io/en/latest/_static/favicon.ico’
#
# docs.argilla.io/en/ 100%[===================>]  14,73K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:20 (1,76 GB/s) - ‘docs.argilla.io/en/latest/_static/favicon.ico’ saved [15086/15086]
#
# --2024-02-14 12:43:20--  https://docs.argilla.io/en/latest/_static/pygments.css
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/en/latest/_static/pygments.css’
#
# docs.argilla.io/en/     [ <=>                ]  19,38K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:20 (189 MB/s) - ‘docs.argilla.io/en/latest/_static/pygments.css’ saved [19847]
#
# --2024-02-14 12:43:20--  https://docs.argilla.io/en/latest/_static/styles/furo.css?digest=e6660623a769aa55fea372102b9bf3151b292993
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/en/latest/_static/styles/furo.css@digest=e6660623a769aa55fea372102b9bf3151b292993.css’
#
# docs.argilla.io/en/     [ <=>                ]  47,08K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:21 (138 MB/s) - ‘docs.argilla.io/en/latest/_static/styles/furo.css@digest=e6660623a769aa55fea372102b9bf3151b292993.css’ saved [48206]
#
# --2024-02-14 12:43:21--  https://docs.argilla.io/en/latest/_static/copybutton.css
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/en/latest/_static/copybutton.css’
#
# docs.argilla.io/en/     [ <=>                ]   2,01K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:21 (491 MB/s) - ‘docs.argilla.io/en/latest/_static/copybutton.css’ saved [2060]
#
# --2024-02-14 12:43:21--  https://docs.argilla.io/en/latest/_static/design-style.1e8bd061cd6da7fc9cf755528e8ffc24.min.css
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/en/latest/_static/design-style.1e8bd061cd6da7fc9cf755528e8ffc24.min.css’
#
# docs.argilla.io/en/     [ <=>                ]  47,28K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:21 (176 MB/s) - ‘docs.argilla.io/en/latest/_static/design-style.1e8bd061cd6da7fc9cf755528e8ffc24.min.css’ saved [48417]
#
# --2024-02-14 12:43:21--  https://docs.argilla.io/_/static/css/badge_only.css
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/_/static/css/badge_only.css’
#
# docs.argilla.io/_/s     [ <=>                ]   3,28K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:22 (267 MB/s) - ‘docs.argilla.io/_/static/css/badge_only.css’ saved [3355]
#
# --2024-02-14 12:43:22--  https://docs.argilla.io/en/latest/_static/styles/furo-extensions.css?digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css’
#
# docs.argilla.io/en/     [ <=>                ]   5,40K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:22 (1,72 GB/s) - ‘docs.argilla.io/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css’ saved [5529]
#
# --2024-02-14 12:43:22--  https://docs.argilla.io/en/latest/_static/css/custom.css
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/en/latest/_static/css/custom.css’
#
# docs.argilla.io/en/     [ <=>                ]  24,35K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:23 (233 MB/s) - ‘docs.argilla.io/en/latest/_static/css/custom.css’ saved [24939]
#
# --2024-02-14 12:43:23--  https://docs.argilla.io/en/latest/_static/documentation_options.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 419 [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/documentation_options.js’
#
# docs.argilla.io/en/ 100%[===================>]     419  --.-KB/s    in 0s
#
# 2024-02-14 12:43:23 (79,9 MB/s) - ‘docs.argilla.io/en/latest/_static/documentation_options.js’ saved [419/419]
#
# --2024-02-14 12:43:23--  https://docs.argilla.io/en/latest/_static/doctools.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4472 (4,4K) [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/doctools.js’
#
# docs.argilla.io/en/ 100%[===================>]   4,37K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:23 (711 MB/s) - ‘docs.argilla.io/en/latest/_static/doctools.js’ saved [4472/4472]
#
# --2024-02-14 12:43:23--  https://docs.argilla.io/en/latest/_static/sphinx_highlight.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4712 (4,6K) [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/sphinx_highlight.js’
#
# docs.argilla.io/en/ 100%[===================>]   4,60K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:24 (899 MB/s) - ‘docs.argilla.io/en/latest/_static/sphinx_highlight.js’ saved [4712/4712]
#
# --2024-02-14 12:43:24--  https://docs.argilla.io/en/latest/_static/scripts/furo.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5275 (5,2K) [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/scripts/furo.js’
#
# docs.argilla.io/en/ 100%[===================>]   5,15K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:24 (2,46 GB/s) - ‘docs.argilla.io/en/latest/_static/scripts/furo.js’ saved [5275/5275]
#
# --2024-02-14 12:43:24--  https://docs.argilla.io/en/latest/_static/clipboard.min.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9031 (8,8K) [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/clipboard.min.js’
#
# docs.argilla.io/en/ 100%[===================>]   8,82K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:24 (146 MB/s) - ‘docs.argilla.io/en/latest/_static/clipboard.min.js’ saved [9031/9031]
#
# --2024-02-14 12:43:24--  https://docs.argilla.io/en/latest/_static/copybutton.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8467 (8,3K) [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/copybutton.js’
#
# docs.argilla.io/en/ 100%[===================>]   8,27K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:25 (1,58 GB/s) - ‘docs.argilla.io/en/latest/_static/copybutton.js’ saved [8467/8467]
#
# --2024-02-14 12:43:25--  https://docs.argilla.io/en/latest/_static/design-tabs.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 770 [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/design-tabs.js’
#
# docs.argilla.io/en/ 100%[===================>]     770  --.-KB/s    in 0s
#
# 2024-02-14 12:43:25 (245 MB/s) - ‘docs.argilla.io/en/latest/_static/design-tabs.js’ saved [770/770]
#
# --2024-02-14 12:43:25--  https://docs.argilla.io/_/static/javascript/readthedocs-doc-embed.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16884 (16K) [text/javascript]
# Saving to: ‘docs.argilla.io/_/static/javascript/readthedocs-doc-embed.js’
#
# docs.argilla.io/_/s 100%[===================>]  16,49K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:25 (75,2 MB/s) - ‘docs.argilla.io/_/static/javascript/readthedocs-doc-embed.js’ saved [16884/16884]
#
# --2024-02-14 12:43:25--  https://docs.argilla.io/en/latest/_static/js/githubStargazers.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2625 (2,6K) [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/js/githubStargazers.js’
#
# docs.argilla.io/en/ 100%[===================>]   2,56K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:26 (626 MB/s) - ‘docs.argilla.io/en/latest/_static/js/githubStargazers.js’ saved [2625/2625]
#
# --2024-02-14 12:43:26--  https://docs.argilla.io/en/latest/_static/js/sidebarScrollPosition.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 409 [text/javascript]
# Saving to: ‘docs.argilla.io/en/latest/_static/js/sidebarScrollPosition.js’
#
# docs.argilla.io/en/ 100%[===================>]     409  --.-KB/s    in 0s
#
# 2024-02-14 12:43:26 (195 MB/s) - ‘docs.argilla.io/en/latest/_static/js/sidebarScrollPosition.js’ saved [409/409]
#
# --2024-02-14 12:43:26--  https://docs.argilla.io/_/static/css/readthedocs-doc-embed.css
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.argilla.io/_/static/css/readthedocs-doc-embed.css’
#
# docs.argilla.io/_/s     [ <=>                ]   6,15K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:26 (1,96 GB/s) - ‘docs.argilla.io/_/static/css/readthedocs-doc-embed.css’ saved [6300]
#
# --2024-02-14 12:43:26--  https://docs.argilla.io/_/static/javascript/readthedocs-analytics.js
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2000 (2,0K) [text/javascript]
# Saving to: ‘docs.argilla.io/_/static/javascript/readthedocs-analytics.js’
#
# docs.argilla.io/_/s 100%[===================>]   1,95K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:26 (636 MB/s) - ‘docs.argilla.io/_/static/javascript/readthedocs-analytics.js’ saved [2000/2000]
#
# --2024-02-14 12:43:26--  https://docs.argilla.io/en/latest/_static/images/logo-light-mode.svg
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/svg+xml]
# Saving to: ‘docs.argilla.io/en/latest/_static/images/logo-light-mode.svg’
#
# docs.argilla.io/en/     [ <=>                ]   3,47K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:27 (339 MB/s) - ‘docs.argilla.io/en/latest/_static/images/logo-light-mode.svg’ saved [3554]
#
# --2024-02-14 12:43:27--  https://docs.argilla.io/en/latest/_static/images/logo-dark-mode.svg
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/svg+xml]
# Saving to: ‘docs.argilla.io/en/latest/_static/images/logo-dark-mode.svg’
#
# docs.argilla.io/en/     [ <=>                ]   6,13K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:27 (749 MB/s) - ‘docs.argilla.io/en/latest/_static/images/logo-dark-mode.svg’ saved [6282]
#
# --2024-02-14 12:43:27--  https://docs.argilla.io/en/latest/getting_started/quickstart_installation.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/quickstart_installation.html’
#
# docs.argilla.io/en/     [ <=>                ]  67,08K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:27 (175 MB/s) - ‘docs.argilla.io/en/latest/getting_started/quickstart_installation.html’ saved [68688]
#
# --2024-02-14 12:43:27--  https://docs.argilla.io/en/latest/getting_started/quickstart_workflow_feedback.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/quickstart_workflow_feedback.html’
#
# docs.argilla.io/en/     [ <=>                ] 122,65K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:27 (69,3 MB/s) - ‘docs.argilla.io/en/latest/getting_started/quickstart_workflow_feedback.html’ saved [125598]
#
# --2024-02-14 12:43:27--  https://docs.argilla.io/en/latest/getting_started/quickstart_workflow.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/quickstart_workflow.html’
#
# docs.argilla.io/en/     [ <=>                ] 158,21K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:27 (97,9 MB/s) - ‘docs.argilla.io/en/latest/getting_started/quickstart_workflow.html’ saved [162006]
#
# --2024-02-14 12:43:27--  https://docs.argilla.io/en/latest/getting_started/cheatsheet.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/cheatsheet.html’
#
# docs.argilla.io/en/     [ <=>                ] 150,50K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:28 (65,0 MB/s) - ‘docs.argilla.io/en/latest/getting_started/cheatsheet.html’ saved [154117]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/deployments.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/deployments.html’
#
# docs.argilla.io/en/     [ <=>                ]  61,21K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:28 (102 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/deployments.html’ saved [62684]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/python.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/python.html’
#
# docs.argilla.io/en/     [ <=>                ]  63,53K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (148 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/python.html’ saved [65050]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/docker.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/docker.html’
#
# docs.argilla.io/en/     [ <=>                ]  63,24K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (126 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/docker.html’ saved [64759]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/docker-quickstart.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/docker-quickstart.html’
#
# docs.argilla.io/en/     [ <=>                ]  63,67K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (153 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/docker-quickstart.html’ saved [65195]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/docker_compose.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/docker_compose.html’
#
# docs.argilla.io/en/     [ <=>                ]  64,71K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (267 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/docker_compose.html’ saved [66260]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/cloud_providers.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/cloud_providers.html’
#
# docs.argilla.io/en/     [ <=>                ]  73,92K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:28 (87,5 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/cloud_providers.html’ saved [75698]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/huggingface-spaces.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/huggingface-spaces.html’
#
# docs.argilla.io/en/     [ <=>                ]  88,92K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:28 (41,6 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/huggingface-spaces.html’ saved [91053]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/deployments/google-colab.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/deployments/google-colab.html’
#
# docs.argilla.io/en/     [ <=>                ]  58,21K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (120 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/deployments/google-colab.html’ saved [59608]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/configurations.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/configurations.html’
#
# docs.argilla.io/en/     [ <=>                ]  62,07K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (151 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/configurations.html’ saved [63559]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/elasticsearch.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/elasticsearch.html’
#
# docs.argilla.io/en/     [ <=>                ]  76,26K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (151 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/elasticsearch.html’ saved [78089]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/server_configuration.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/server_configuration.html’
#
# docs.argilla.io/en/     [ <=>                ]  68,59K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:28 (96,4 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/server_configuration.html’ saved [70241]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/user_management.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/user_management.html’
#
# docs.argilla.io/en/     [ <=>                ]  99,36K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:28 (56,9 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/user_management.html’ saved [101746]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/workspace_management.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/workspace_management.html’
#
# docs.argilla.io/en/     [ <=>                ]  86,59K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:28 (58,2 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/workspace_management.html’ saved [88664]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/database_migrations.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/database_migrations.html’
#
# docs.argilla.io/en/     [ <=>                ]  80,59K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:28 (323 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/database_migrations.html’ saved [82524]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/getting_started/installation/configurations/image_support.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/getting_started/installation/configurations/image_support.html’
#
# docs.argilla.io/en/     [ <=>                ]  59,40K  --.-KB/s    in 0,004s
#
# 2024-02-14 12:43:28 (15,5 MB/s) - ‘docs.argilla.io/en/latest/getting_started/installation/configurations/image_support.html’ saved [60827]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/conceptual_guides/data_model.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/conceptual_guides/data_model.html’
#
# docs.argilla.io/en/     [ <=>                ]  80,69K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:28 (65,8 MB/s) - ‘docs.argilla.io/en/latest/conceptual_guides/data_model.html’ saved [82631]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/conceptual_guides/llm/llm.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/conceptual_guides/llm/llm.html’
#
# docs.argilla.io/en/     [ <=>                ]  59,49K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:28 (46,6 MB/s) - ‘docs.argilla.io/en/latest/conceptual_guides/llm/llm.html’ saved [60917]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/conceptual_guides/llm/rlhf.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/conceptual_guides/llm/rlhf.html’
#
# docs.argilla.io/en/     [ <=>                ]  67,40K  --.-KB/s    in 0,003s
#
# 2024-02-14 12:43:28 (21,1 MB/s) - ‘docs.argilla.io/en/latest/conceptual_guides/llm/rlhf.html’ saved [69020]
#
# --2024-02-14 12:43:28--  https://docs.argilla.io/en/latest/conceptual_guides/llm/sft.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/conceptual_guides/llm/sft.html’
#
# docs.argilla.io/en/     [ <=>                ]  81,20K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:29 (208 MB/s) - ‘docs.argilla.io/en/latest/conceptual_guides/llm/sft.html’ saved [83152]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/conceptual_guides/llm/rm.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/conceptual_guides/llm/rm.html’
#
# docs.argilla.io/en/     [ <=>                ]  90,19K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:29 (307 MB/s) - ‘docs.argilla.io/en/latest/conceptual_guides/llm/rm.html’ saved [92356]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/practical_guides.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/practical_guides.html’
#
# docs.argilla.io/en/     [ <=>                ]  61,32K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:29 (275 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/practical_guides.html’ saved [62792]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/choose_dataset.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/choose_dataset.html’
#
# docs.argilla.io/en/     [ <=>                ]  67,17K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:29 (69,4 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/choose_dataset.html’ saved [68782]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/create_update_dataset/create_dataset.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/create_dataset.html’
#
# docs.argilla.io/en/     [ <=>                ] 154,22K  --.-KB/s    in 0,003s
#
# 2024-02-14 12:43:29 (49,4 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/create_dataset.html’ saved [157919]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/create_update_dataset/records.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/records.html’
#
# docs.argilla.io/en/     [ <=>                ] 113,26K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:29 (47,6 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/records.html’ saved [115975]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/create_update_dataset/metadata.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/metadata.html’
#
# docs.argilla.io/en/     [ <=>                ]  90,94K  --.-KB/s    in 0,004s
#
# 2024-02-14 12:43:29 (20,6 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/metadata.html’ saved [93125]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/create_update_dataset/vectors.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/vectors.html’
#
# docs.argilla.io/en/     [ <=>                ]  81,86K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:29 (153 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/vectors.html’ saved [83827]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/create_update_dataset/suggestions_and_responses.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/suggestions_and_responses.html’
#
# docs.argilla.io/en/     [ <=>                ]  96,97K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:29 (54,3 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/create_update_dataset/suggestions_and_responses.html’ saved [99298]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/assign_records.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/assign_records.html’
#
# docs.argilla.io/en/     [ <=>                ]  78,78K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:29 (359 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/assign_records.html’ saved [80666]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/filter_dataset.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/filter_dataset.html’
#
# docs.argilla.io/en/     [ <=>                ] 126,31K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:29 (235 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/filter_dataset.html’ saved [129340]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/annotate_dataset.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotate_dataset.html’
#
# docs.argilla.io/en/     [ <=>                ]  90,62K  --.-KB/s    in 0,005s
#
# 2024-02-14 12:43:29 (19,6 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotate_dataset.html’ saved [92791]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/annotation_workflows/annotation_workflows.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/annotation_workflows.html’
#
# docs.argilla.io/en/     [ <=>                ]  59,89K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:29 (140 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/annotation_workflows.html’ saved [61324]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/annotation_workflows/active_learning.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/active_learning.html’
#
# docs.argilla.io/en/     [ <=>                ]  59,23K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:29 (27,9 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/active_learning.html’ saved [60649]
#
# --2024-02-14 12:43:29--  https://docs.argilla.io/en/latest/practical_guides/annotation_workflows/weak_supervision.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/weak_supervision.html’
#
# docs.argilla.io/en/     [ <=>                ] 160,03K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (184 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/weak_supervision.html’ saved [163869]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/practical_guides/annotation_workflows/semantic_search.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/semantic_search.html’
#
# docs.argilla.io/en/     [ <=>                ] 100,67K  --.-KB/s    in 0,004s
#
# 2024-02-14 12:43:30 (23,5 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/semantic_search.html’ saved [103088]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/practical_guides/annotation_workflows/job_scheduling.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/job_scheduling.html’
#
# docs.argilla.io/en/     [ <=>                ]  69,55K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (61,2 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/job_scheduling.html’ saved [71220]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/practical_guides/annotation_workflows/add_text_descriptives_as_metadata.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/add_text_descriptives_as_metadata.html’
#
# docs.argilla.io/en/     [ <=>                ] 225,11K  --.-KB/s    in 0,003s
#
# 2024-02-14 12:43:30 (70,7 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/annotation_workflows/add_text_descriptives_as_metadata.html’ saved [230514]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/practical_guides/collect_responses.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/collect_responses.html’
#
# docs.argilla.io/en/     [ <=>                ] 130,96K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (155 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/collect_responses.html’ saved [134101]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/practical_guides/export_dataset.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/export_dataset.html’
#
# docs.argilla.io/en/     [ <=>                ]  82,83K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:30 (51,4 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/export_dataset.html’ saved [84820]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/practical_guides/fine_tune.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/practical_guides/fine_tune.html’
#
# docs.argilla.io/en/     [ <=>                ] 317,03K  --.-KB/s    in 0,006s
#
# 2024-02-14 12:43:30 (52,4 MB/s) - ‘docs.argilla.io/en/latest/practical_guides/fine_tune.html’ saved [324638]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/tutorials.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/tutorials.html’
#
# docs.argilla.io/en/     [ <=>                ]  76,83K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (66,9 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/tutorials.html’ saved [78671]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/integrations/integrations.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/integrations.html’
#
# docs.argilla.io/en/     [ <=>                ]  60,23K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (109 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/integrations.html’ saved [61678]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/integrations/use_argilla_callback_in_langchain.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/use_argilla_callback_in_langchain.html’
#
# docs.argilla.io/en/     [ <=>                ]  82,26K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (102 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/use_argilla_callback_in_langchain.html’ saved [84235]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/integrations/process_documents_with_unstructured.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/process_documents_with_unstructured.html’
#
# docs.argilla.io/en/     [ <=>                ] 117,21K  --.-KB/s    in 0,005s
#
# 2024-02-14 12:43:30 (21,2 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/process_documents_with_unstructured.html’ saved [120019]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/integrations/monitor_endpoints%20with_fastapi.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/monitor_endpoints with_fastapi.html’
#
# docs.argilla.io/en/     [ <=>                ] 131,00K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:30 (58,0 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/monitor_endpoints with_fastapi.html’ saved [134144]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_text_descriptives_as_metadata.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_text_descriptives_as_metadata.html’
#
# docs.argilla.io/en/     [ <=>                ] 226,01K  --.-KB/s    in 0,003s
#
# 2024-02-14 12:43:30 (77,1 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_text_descriptives_as_metadata.html’ saved [231432]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_sentence_transformers_embeddings_as_vectors.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_sentence_transformers_embeddings_as_vectors.html’
#
# docs.argilla.io/en/     [ <=>                ]  86,29K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:30 (115 MB/s) - ‘docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_sentence_transformers_embeddings_as_vectors.html’ saved [88360]
#
# --2024-02-14 12:43:30--  https://docs.argilla.io/en/latest/reference/python/index.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/index.html’
#
# docs.argilla.io/en/     [ <=>                ]  59,14K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:31 (99,4 MB/s) - ‘docs.argilla.io/en/latest/reference/python/index.html’ saved [60559]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_client.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_client.html’
#
# docs.argilla.io/en/     [ <=>                ] 502,17K  --.-KB/s    in 0,01s
#
# 2024-02-14 12:43:31 (40,5 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_client.html’ saved [514227]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_metrics.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_metrics.html’
#
# docs.argilla.io/en/     [ <=>                ] 111,13K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:31 (58,5 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_metrics.html’ saved [113796]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_labeling.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_labeling.html’
#
# docs.argilla.io/en/     [ <=>                ] 145,67K  --.-KB/s    in 0,003s
#
# 2024-02-14 12:43:31 (44,9 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_labeling.html’ saved [149169]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_training.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_training.html’
#
# docs.argilla.io/en/     [ <=>                ] 211,97K  --.-KB/s    in 0,008s
#
# 2024-02-14 12:43:31 (27,0 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_training.html’ saved [217055]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_monitoring.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_monitoring.html’
#
# docs.argilla.io/en/     [ <=>                ]  91,50K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:31 (355 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_monitoring.html’ saved [93695]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_listeners.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_listeners.html’
#
# docs.argilla.io/en/     [ <=>                ]  76,38K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:31 (70,7 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_listeners.html’ saved [78210]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_users.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_users.html’
#
# docs.argilla.io/en/     [ <=>                ]  84,56K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:31 (223 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_users.html’ saved [86590]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_workspaces.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_workspaces.html’
#
# docs.argilla.io/en/     [ <=>                ]  81,78K  --.-KB/s    in 0s
#
# 2024-02-14 12:43:31 (189 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_workspaces.html’ saved [83745]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/python/python_annotation_metrics.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/python/python_annotation_metrics.html’
#
# docs.argilla.io/en/     [ <=>                ]  58,73K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:31 (57,9 MB/s) - ‘docs.argilla.io/en/latest/reference/python/python_annotation_metrics.html’ saved [60142]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/cli.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/cli.html’
#
# docs.argilla.io/en/     [ <=>                ]  77,59K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:31 (68,5 MB/s) - ‘docs.argilla.io/en/latest/reference/cli.html’ saved [79452]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/webapp/index.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/webapp/index.html’
#
# docs.argilla.io/en/     [ <=>                ]  58,07K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:31 (44,0 MB/s) - ‘docs.argilla.io/en/latest/reference/webapp/index.html’ saved [59467]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/webapp/pages.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/webapp/pages.html’
#
# docs.argilla.io/en/     [ <=>                ]  75,35K  --.-KB/s    in 0,002s
#
# 2024-02-14 12:43:31 (41,7 MB/s) - ‘docs.argilla.io/en/latest/reference/webapp/pages.html’ saved [77159]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/webapp/features.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/webapp/features.html’
#
# docs.argilla.io/en/     [ <=>                ]  93,84K  --.-KB/s    in 0,001s
#
# 2024-02-14 12:43:31 (79,8 MB/s) - ‘docs.argilla.io/en/latest/reference/webapp/features.html’ saved [96094]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/reference/notebooks.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.argilla.io/en/latest/reference/notebooks.html’
#
# docs.argilla.io/en/     [ <=>                ] 110,71K  --.-KB/s    in 0,003s
#
# 2024-02-14 12:43:31 (31,3 MB/s) - ‘docs.argilla.io/en/latest/reference/notebooks.html’ saved [113368]
#
# --2024-02-14 12:43:31--  https://docs.argilla.io/en/latest/tutorials/notebooks/deploying-text2text-dvc-explainability.html
# Reusing existing connection to docs.argilla.io:443.
# HTTP request sent, awaiting response... 200 OK
# ...
# 170-121
# Converting links in docs.argilla.io/en/latest/reference/python/python_workspaces.html... 294.
# 173-121
# Converting links in docs.argilla.io/en/latest/practical_guides/annotation_workflows/active_learning.html... 266.
# 145-121
# Converting links in docs.argilla.io/en/latest/tutorials/techniques/few_shot.html... 273.
# 150-123
# Converting links in docs.argilla.io/en/latest/reference/python/python_metrics.html... 321.
# 200-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/other_datasets/few_shot_text_classification_with_active_learning.html... 285.
# 156-129
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/classyclassification.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/configurations/user_management.html... 302.
# 181-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-textclassification-sentencetransformers-weaksupervision.html... 318.
# 197-121
# Converting links in docs.argilla.io/en/latest/practical_guides/assign_records.html... 281.
# 160-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/flair.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-textclassification-sentencetransformers-semantic.html... 298.
# 177-121
# Converting links in docs.argilla.io/en/latest/getting_started/cheatsheet.html... 305.
# 184-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/deploying-text2text-dvc-explainability.html... 282.
# 161-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/train-model-006.html... 295.
# 174-121
# Converting links in docs.argilla.io/en/latest/tutorials/techniques/weak_supervision.html... 263.
# 142-121
# Converting links in docs.argilla.io/en/latest/reference/notebooks.html... 524.
# 403-121
# Converting links in docs.argilla.io/en/latest/community/contributing.html... 314.
# 193-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/add-metadata-003.html... 313.
# 192-121
# Converting links in docs.argilla.io/en/latest/practical_guides/create_update_dataset/records.html... 309.
# 188-121
# Converting links in docs.argilla.io/en/latest/practical_guides/filter_dataset.html... 328.
# 207-121
# Converting links in docs.argilla.io/en/latest/tutorials/steps/1_labelling.html... 287.
# 165-122
# Converting links in docs.argilla.io/en/latest/getting_started/quickstart.html... 262.
# 141-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/monitoring-textclassification-shaptransformersinterpret-explainability.html... 277.
# 156-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/spacy.html... 259.
# 138-121
# Converting links in docs.argilla.io/en/latest/tutorials/steps/4_monitoring.html... 267.
# 146-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/snorkel.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-tokenclassification-using-spacy-llm.html... 287.
# 166-121
# Converting links in docs.argilla.io/en/latest/practical_guides/annotation_workflows/annotation_workflows.html... 264.
# 143-121
# Converting links in docs.argilla.io/en/latest/tutorials/techniques/explainability.html... 271.
# 150-121
# Converting links in docs.argilla.io/en/latest/getting_started/quickstart_workflow.html... 305.
# 182-123
# Converting links in docs.argilla.io/en/latest/reference/python/python_labeling.html... 354.
# 233-121
# Converting links in docs.argilla.io/en/latest/practical_guides/annotation_workflows/weak_supervision.html... 313.
# 191-122
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/training-textgeneration-unstructured.html... 278.
# 157-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/monitoring-bias-ethics-dpo.html... 280.
# 157-123
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/integrations/monitor_endpoints with_fastapi.html... 288.
# 167-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/deployments/docker_compose.html... 265.
# 144-121
# Converting links in docs.argilla.io/en/latest/reference/python/python_client.html... 736.
# 615-121
# Converting links in docs.argilla.io/en/latest/tutorials/tutorials.html... 299.
# 178-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/training-textclassification-classyclassification-activelearning.html... 285.
# 162-123
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_text_descriptives_as_metadata.html... 285.
# 163-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/integrations/process_documents_with_unstructured.html... 275.
# 154-121
# Converting links in docs.argilla.io/en/latest/search.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/practical_guides/fine_tune.html... 373.
# 252-121
# Converting links in docs.argilla.io/en/latest/index.html... 288.
# 164-124
# Converting links in docs.argilla.io/en/latest/community/migration-rubrix.html... 268.
# 147-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/configurations/server_configuration.html... 284.
# 163-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/deployments/deployments.html... 266.
# 145-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/other_datasets/few_shot_learning_with_setfit.html... 274.
# 149-125
# Converting links in docs.argilla.io/en/latest/conceptual_guides/llm/rlhf.html... 265.
# 144-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/fine-tuning-sentencesimilarity-rag.html... 290.
# 162-128
# Converting links in docs.argilla.io/en/latest/getting_started/installation/configurations/database_migrations.html... 278.
# 157-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/bentoml.html... 258.
# 137-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/deploying-textclassification-colab-activelearning.html... 282.
# 161-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/other_datasets/label_errors_cleanlab.html... 280.
# 156-124
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-textclassification-sentence-transformers-semantic.html... 293.
# 172-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/add-vectors-004.html... 309.
# 188-121
# Converting links in docs.argilla.io/en/latest/practical_guides/annotate_dataset.html... 342.
# 221-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/training-textclassification-smalltext-activelearning.html... 289.
# 166-123
# Converting links in docs.argilla.io/en/latest/practical_guides/create_update_dataset/vectors.html... 289.
# 168-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-tokenclassification-basics.html... 293.
# 172-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/add-suggestions-and-responses-005.html... 313.
# 192-121
# Converting links in docs.argilla.io/en/latest/reference/python/python_listeners.html... 295.
# 174-121
# Converting links in docs.argilla.io/en/latest/tutorials/steps/3_deploying.html... 261.
# 140-121
# Converting links in docs.argilla.io/en/latest/reference/python/python_annotation_metrics.html... 268.
# 147-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/ner_fine_tune_bert_beginners.html... 289.
# 167-122
# Converting links in docs.argilla.io/en/latest/reference/python/python_monitoring.html... 322.
# 201-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/training-textclassification-transformers-pretrained.html... 309.
# 187-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/integrations/integrations.html... 264.
# 142-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/labelling-spacy-llm.html... 278.
# 156-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/other_datasets/weak_supervision_text_classification_semantic_search.html... 315.
# 187-128
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-textclassification-gpt3-fewshot.html... 285.
# 164-121
# Converting links in docs.argilla.io/en/latest/practical_guides/choose_dataset.html... 272.
# 151-121
# Converting links in docs.argilla.io/en/latest/reference/webapp/features.html... 408.
# 287-121
# Converting links in docs.argilla.io/en/latest/tutorials/techniques/active_learning.html... 263.
# 142-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/integrations/add_sentence_transformers_embeddings_as_vectors.html... 284.
# 162-122
# Converting links in docs.argilla.io/en/latest/getting_started/installation/configurations/workspace_management.html... 300.
# 179-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/configure-users-and-workspaces-000.html... 285.
# 164-121
# Converting links in docs.argilla.io/en/latest/conceptual_guides/llm/sft.html... 280.
# 159-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/sentencetransformers.html... 261.
# 140-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/configurations/image_support.html... 266.
# 145-121
# Converting links in docs.argilla.io/en/latest/reference/python/python_users.html... 307.
# 186-121
# Converting links in docs.argilla.io/en/latest/reference/telemetry.html... 268.
# 147-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/training-qa-transformers.html... 284.
# 161-123
# Converting links in docs.argilla.io/en/latest/reference/webapp/index.html... 261.
# 140-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/training-textclassification-setfit-sentiment.html... 285.
# 163-122
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/fastapi.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/reference/python/index.html... 268.
# 147-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/assign-records-002.html... 309.
# 188-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/dvc.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-textclassification-snorkel-weaksupervision.html... 288.
# 167-121
# Converting links in docs.argilla.io/en/latest/getting_started/quickstart_installation.html... 277.
# 156-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/setfit.html... 267.
# 144-123
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/skweak.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-tokenclassification-deletelabels.html... 275.
# 154-121
# Converting links in docs.argilla.io/en/latest/practical_guides/annotation_workflows/add_text_descriptives_as_metadata.html... 285.
# 163-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/fine-tuning-openai-rag-feedback.html... 282.
# 160-122
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/openai.html... 259.
# 137-122
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/transformersinterpret.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/community/developer_docs.html... 326.
# 205-121
# Converting links in docs.argilla.io/en/latest/practical_guides/create_update_dataset/metadata.html... 288.
# 167-121
# Converting links in docs.argilla.io/en/latest/tutorials/tasks/text_generation.html... 259.
# 138-121
# Converting links in docs.argilla.io/en/latest/getting_started/quickstart_workflow_feedback.html... 293.
# 170-123
# Converting links in docs.argilla.io/en/latest/getting_started/installation/configurations/configurations.html... 265.
# 144-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/integrations/use_argilla_callback_in_langchain.html... 278.
# 157-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-spacy-llm.html... 282.
# 161-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/monitoring-textclassification-setfit-explainability.html... 276.
# 155-121
# Converting links in docs.argilla.io/en/latest/practical_guides/create_update_dataset/suggestions_and_responses.html... 289.
# 168-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/other_datasets/label_data_with_semantic_search.html... 289.
# 165-124
# Converting links in docs.argilla.io/en/latest/practical_guides/create_update_dataset/create_dataset.html... 326.
# 205-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-textclassification-setfit-zeroshot.html... 286.
# 164-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/labelling-feedback-langchain-syntethic.html... 299.
# 177-122
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-tokenclassification-skweak-weaksupervision.html... 301.
# 180-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/langchain.html... 257.
# 135-122
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/other_datasets/weak_supervision_ner.html... 297.
# 174-123
# Converting links in docs.argilla.io/en/latest/conceptual_guides/data_model.html... 315.
# 194-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/use-metrics-007.html... 296.
# 173-123
# Converting links in docs.argilla.io/en/latest/conceptual_guides/llm/llm.html... 263.
# 142-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/deployments/docker-quickstart.html... 263.
# 142-121
# Converting links in docs.argilla.io/en/latest/practical_guides/collect_responses.html... 325.
# 204-121
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/smalltext.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/end2end_examples/create-dataset-001.html... 297.
# 176-121
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/training-llm-mistral-sft.html... 308.
# 185-123
# Converting links in docs.argilla.io/en/latest/tutorials_and_integrations/tutorials/feedback/trainer-feedback-setfit.html... 279.
# 154-125
# Converting links in docs.argilla.io/en/latest/tutorials/libraries/colab.html... 257.
# 136-121
# Converting links in docs.argilla.io/en/latest/getting_started/installation/deployments/huggingface-spaces.html... 288.
# 167-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/deploying-texttokenclassification-fastapi.html... 291.
# 170-121
# Converting links in docs.argilla.io/en/latest/tutorials/notebooks/labelling-tokenclassification-spacy-pretrained.html... 281.
# 160-121
# Converting links in docs.argilla.io/_/static/css/badge_only.css... 5.
# 5-0
# Converting links in docs.argilla.io/en/latest/_static/css/custom.css... 6.
# 6-0
# Converting links in docs.argilla.io/en/latest/_static/pygments.css... nothing to do.
# Converting links in docs.argilla.io/_/static/css/readthedocs-doc-embed.css... nothing to do.
# Converting links in docs.argilla.io/en/latest/_static/styles/furo.css@digest=e6660623a769aa55fea372102b9bf3151b292993.css... nothing to do.
# Converting links in docs.argilla.io/en/latest/_static/copybutton.css... nothing to do.
# Converting links in docs.argilla.io/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css... nothing to do.
# Converting links in docs.argilla.io/en/latest/_static/design-style.1e8bd061cd6da7fc9cf755528e8ffc24.min.css... nothing to do.
# Converted links in 175 files in 0,4 seconds.

# %%
reader = UnstructuredReader()

all_files_gen = Path("./docs.argilla.io/").rglob("*")
all_files = [f.resolve() for f in all_files_gen]

all_html_files = [f for f in all_files if f.suffix.lower() == ".html"]

print(f"Number of documents downloaded: {len(all_html_files)}")
# Out:
# Number of documents downloaded: 169
# [nltk_data] Downloading package punkt to /Users/ignacio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/ignacio/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
docs = []

for idx, f in enumerate(all_html_files):

    # The first three elements of the docs are indexes, so we can skip them.
    if idx < 3:
        continue
    
    # We also need to handle exceptions when images are found among the html files.
    try:
        loaded_docs = reader.load_data(file=f, split_documents=True)
    except NameError:
        print(f"Error loading {f}, was a image. Skipping.")
        continue
    
    loaded_doc = Document(
        text="\n\n".join([d.get_content() for d in loaded_docs]),
        metadata={"path": str(f)},
    )
    docs.append(loaded_doc)
# Out:
# Error loading /Users/ignacio/Documents/recognai/argilla-llama-index/docs/tutorials/docs.argilla.io/en/latest/_images/token_length_plot.png.html, was a image. Skipping.

# %%
# Print each field and its content from the an element of the list of docs.
for elem in docs[10].__dict__:
    print(f"{elem}: {docs[10].__dict__[elem]}")
# Out:
# id_: d83c68fc-ed91-4dca-89d6-befae4b04b46
# embedding: None
# metadata: {'path': '/Users/ignacio/Documents/recognai/argilla-llama-index/docs/tutorials/docs.argilla.io/en/latest/practical_guides/practical_guides.html'}
# excluded_embed_metadata_keys: []
# excluded_llm_metadata_keys: []
# relationships: {}
# text: Hide navigation sidebar
#
# Hide table of contents sidebar
#
# Hide search
#
# Toggle site navigation sidebar
#
# Toggle search
#
# Hide search
#
# Toggle Light / Dark / Auto color theme
#
# Join
#
# Getting Started
#
# What is Argilla?
#
# 🚀 QuickstartToggle navigation of 🚀 Quickstart
# Installation
# Workflow Feedback Dataset
# Workflow of Other Datasets
#
# 🎼 Cheatsheet
#
# 🔧 InstallationToggle navigation of 🔧 Installation
# Python
# Docker
# Docker Quickstart
# Docker-compose
# Cloud Providers and Kubernetes
# Hugging Face Spaces
# Google Colab
#
# ⚙️ ConfigurationToggle navigation of ⚙️ Configuration
# Elasticsearch
# Server configuration
# User Management
# Workspace and Dataset Management
# Database Migrations
# Image Support
#
# Conceptual Guides
#
# Argilla concepts
#
# Data collection for LLMsToggle navigation of Data collection for LLMs
# Collecting RLHF data
# Collecting demonstration data
# Collecting comparison data
#
# Practical Guides
#
# 🗺️ Practical guides overview
#
# 🧐 Choose a dataset type
#
# 🧑‍💻 Create and update a datasetToggle navigation of 🧑‍💻 Create and update a dataset
# ⏺️ Add and update records
# 💾 Work with metadata
# 🎫 Work with vectors
# 🤔 Work with suggestions and responses
#
# 🗂️ Assign records to your team
#
# 🔎 Filter and query datasets
#
# ✍️ Annotate a  dataset
#
# 🌊 Simplify annotation with machine feedback workflowsToggle navigation of 🌊 Simplify annotation with machine feedback workflows
# 🧑‍🏫 Active Learning
# 👮 Weak Supervision
# 🔦 Semantic Search
# ⏲️ Job Scheduling and Callbacks
# 📇 Add Text Descriptives as Metadata
#
# 📊 Collect responses and metrics
#
# 📥 Export a dataset
#
# 🦾 Fine-tune LLMs and other language models
#
# Tutorials and Integrations
#
# Tutorials
#
# IntegrationsToggle navigation of Integrations
# langchain: Monitoring LLMs in apps, chains, and agents and tools
# unstructured: Large-scale document processing for LLMs
# fastapi: Monitor NLP models with ArgillaLogHTTPMiddleware
# textdescriptives: Add basic descriptive features as Metadata
# sentence-transformers: Add semantic vectors to your dataset
#
# Reference
#
# PythonToggle navigation of Python
# Client
# Metrics
# Labeling
# Training
# Monitoring
# Listeners
# Users
# Workspaces
# Annotation metrics
#
# CLI
#
# Argilla UIToggle navigation of Argilla UI
# Pages
# Features
#
# NotebooksToggle navigation of Notebooks
# 🔐 Backup and version Argilla Datasets using DVC
# 🚀 Run Argilla with a Transformer in an active learning loop and a free GPU in your browser
# 💾 Monitor FastAPI model endpoints
# 🧸 Using LLMs for Text Classification and Summarization Suggestions with spacy-llm
# 🗺️ Add bias-equality features to datasets with disaggregators
# 💡 Build and evaluate a zero-shot sentiment classifier with GPT-3
# 💨 Label data with semantic search and Sentence Transformers
# 📸 Bulk Labeling Multimodal Data
# 🧱 Augment weak supervision rules with Sentence Transformers
# 🔫 Zero-shot and few-shot classification with SetFit
# 🗂 Multi-label text classification with weak supervision
# 📰 Train a text classifier with weak supervision
# 🗂️ Assign records to your annotation team
# 🩹 Delete labels from a Token or Text Classification dataset
# 🔫 Evaluate a zero-shot NER with Flair
# 🐭 Train a NER model with skweak
# 💫 Explore and analyze spaCy NER predictions
# 🔗 Using LLMs for Few-Shot Token Classification Suggestions with spacy-llm
# 🧐 Find label errors with cleanlab
# 🥇 Compare Text Classification Models
# 🕵️‍♀️ Analyze predictions with explainability methods
# 🧼 Clean labels using your model’s loss
# 🤔 Fine-tunning a NER model with BERT for Beginners
# Text classification active learning with classy-classification
# 🤔 Text Classification active learning with ModAL
# 🤯 Few-shot classification with SetFit
# 🤗 Train a sentiment classifier with SetFit
# 👂 Text Classification: Active Learning with small-text
# 🏷️ Fine-tune a sentiment classifier with your own data
# 🕸️ Train a summarization model with Unstructured and Transformers
#
# Telemetry
#
# Community
#
# Slack
#
# Github
#
# Developer Documentation
#
# Contributor Documentation
#
# Migration from Rubrix
#
# v: latest
#
# latest
#
# v1.24.0
#
# v1.23.0
#
# v1.22.0
#
# v1.21.0
#
# v1.20.0
#
# v1.19.0
#
# v1.18.0
#
# v1.17.0
#
# v1.16.0
#
# v1.15.0
#
# v1.14.0
#
# v1.13.0
#
# v1.12.0
#
# v1.11.0
#
# v1.10.0
#
# v1.9.0
#
# v1.8.0
#
# v1.7.0
#
# v1.6.0
#
# v1.5.0
#
# v1.4.0
#
# v1.3.0
#
# v1.2.0
#
# v1.1.0
#
# update-changelog-for-singlelabel-multilabel
#
# test-bulk-annotation
#
# temporal-has-no-records-similarity
#
# releases-v1.9.0
#
# releases-1.8.0
#
# releases-1.24.0
#
# releases-1.23.0
#
# releases-1.22.0
#
# releases-1.21.0
#
# releases-1.20.0
#
# releases-1.19.0
#
# releases-1.18.0
#
# releases-1.17.0
#
# releases-1.15.1
#
# releases-1.13.3
#
# releases-1.13.2
#
# releases-1.13.1
#
# releases-1.13.0
#
# releases-1.12.1
#
# releases-1.11.0
#
# releases-1.10.0
#
# refactor-using-more-general-409-api-error
#
# refactor-review-server-app-configuration
#
# refactor-poc-change-component-questionform-to-composition-api
#
# refactor-pagination-component
#
# refactor-configure-elasticsearch-timeouts
#
# pre-commit-ci-update-config
#
# fix-remove-sanitize-html
#
# fix-python-3-11-compatibility-tests
#
# fix-push-to-hugging-face-yaml-export
#
# fix-missing-metadata-in-sort-by
#
# fix-frontend-dependencies
#
# fix-close-pr-2
#
# fix-broken_unit_test
#
# fix-babel-wrong-import-dependency
#
# feature-update_pydantic_v2
#
# feature-refresh-search-index-endpoint
#
# feature-improve-error-traceback-httpx
#
# feature-huggingface-agents-integration
#
# feature-environment-per-branch-2
#
# feature-delete-suggestion-from-search-engine
#
# feature-ci-runtime-improvements
#
# feature-background-tasks-poc
#
# feature-add-vector-settings-patch-endpoint
#
# feat-trl_callback
#
# feat-span-question
#
# feat-space-info-from-token
#
# feat-similarity-qa-pr
#
# feat-sign-up-support
#
# feat-responses-and-suggestions-filters-components
#
# feat-resize-annotation-mode
#
# feat-required-widget-for-question
#
# feat-remove-unused-hf-url
#
# feat-refactor-argilla-trainer
#
# feat-poc-change-questionsform-to-composition-api
#
# feat-page-buffering
#
# feat-new_sdk
#
# feat-metrics
#
# feat-local-remote-alignment
#
# feat-improve-pagination
#
# feat-hd-sign-in
#
# feat-feedback_task_helpbox
#
# feat-basic-oauth-integration
#
# feat-allow-pass-extra-config-to-search-backend-client
#
# feat-add-rq
#
# feat-4437-feature-add-tests-to-textdescriptives-for-remote-part
#
# feat-4134-feature-add-rgwhoami-method-and-potential-show-info-during-initlogin
#
# feat-3764-feature-add-rgfeedbackdatasetfor_task-for-commonly-used-task-schemas
#
# feat-3616-autotrain
#
# feat-2259-feature-add-__repr__-for-the-sdk-classes
#
# docs-suggestions-peppinob-ol
#
# docs-spanmarker_tutorial
#
# docs-fine-tune-openai-rag
#
# docs-correct-version
#
# docs-add_rm_example_trl_01
#
# docs-4567-docs-update-example-in-hf-spaces-page
#
# docs-4234-docs-add-telemetry-reference-to-the-tutorials-to-track-their-usage
#
# docs-4181-docs-example-on-adding-metadata-to-a-text-classification-dataset
#
# docs-4107-docs-change-warning-to-info-admonition
#
# docs-3609-docs-add-visualisation-to-docs-wrt-argilla-structure
#
# develop
#
# dependabot-pip-wrapt-gte-1.13-and-lt-1.16
#
# dependabot-pip-uvicorn-standard-gte-0.15.0-and-lt-0.24.0
#
# dependabot-pip-pandas-gte-1.0.0-and-lt-3.0.0
#
# dependabot-pip-opensearch-py-gte-2.0-and-lt-2.4
#
# ci-change-default-board-for-new-issues
#
# chore-tests-improvements
#
# chore-ruff-unused-imports
#
# chore-merge-branch-from-develop
#
# bugfixes-record-responses-are-not-validated-before-send-them-to-argilla
#
# 4024-feature-create-a-task-template-for-preference-data-collection
#
# 3935-improvement-improve-the-feedbackdataset__repr__-method
#
# 3895-docs-blogpost-on-a-qa-workflow-1
#
# 3895-docs-blogpost-on-a-qa-workflow
#
# 3824-feature-display-information-on-feedbackdatasetpush_to_argilla
#
# Project Home
#
# Builds
#
# Back to top
#
# Toggle Light / Dark / Auto color theme
#
# Toggle table of contents sidebar
#
# Join
#
# 🗺️ Practical guides overview#
#
# This guide will help you with all the practical aspects of setting up an annotation project for training and fine-tuning LLMs using Argilla’s Feedback Task Datasets. It covers everything from defining your task to collecting, organizing, and using the feedback effectively.
#
# 🧐 Choose a dataset type
#
# Find the dataset type needed for your project.
#
# 🧑‍💻 Create and update a dataset
#
# Methods to create and configure a dataset.
#
# 🗂️ Assign records to your team
#
# Workflows to organize your annotation team.
#
# 🔎 Filter and query datasets
#
# Obtain a filtered version of your dataset.
#
# ✍️ Annotate a dataset
#
# Learn to use Argilla’s UI and its features.
#
# 🌊 Simplify annotation with machine feedback workflow
#
# Use things like active learning, weak supervision, semantic search, and job scheduling.
#
# 📊 Collect responses and metrics
#
# Collect responses, get metrics, and solve disagreements.
#
# 📥 Export a dataset
#
# Export your dataset and save it in the Hugging Face Hub or locally.
#
# 🦾 Fine-tune LLMs and other models
#
# Fine-tune an LLM or other models with the feedback collected from Argilla.
#
# Next
#
#               🧐 Choose a dataset type
#
# Previous
#
#
#               Collecting comparison data
#
# Copyright © 2024, Argilla.io
#
#             Made with
#
# Sphinx and
#
# @pradyunsg's
#
# Furo
#
# Signup Here For
#
# Our Community Meetup
# start_char_idx: None
# end_char_idx: None
# text_template: {metadata_str}
#
# {content}
# metadata_template: {key}: {value}
# metadata_seperator:

# %% [markdown]
# ## Load the LLM and the Argilla handler

# %%
# If you don't have your key in an environment variable, you can fill this constant with your API KEY.
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

nest_asyncio.apply()

# %%
OPENAI_API_KEY
# Out:
# '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'

# %%
set_global_handler("argilla", dataset_name="query_model")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/llama_i │
# │ ndex/callbacks/argilla/base.py:9 in argilla_callback_handler                                     │
# │                                                                                                  │
# │    6 def argilla_callback_handler(**kwargs: Any) -> BaseCallbackHandler:                         │
# │    7 │   try:                                                                                    │
# │    8 │   │   # lazy import                                                                       │
# │ ❱  9 │   │   from argilla_llama_index import ArgillaCallbackHandler                              │
# │   10 │   except ImportError:                                                                     │
# │   11 │   │   raise ImportError("Please install Argilla with `pip install argilla`")              │
# │   12 │   return ArgillaCallbackHandler(**kwargs)                                                 │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/argilla │
# │ _llama_index/__init__.py:17 in <module>                                                          │
# │                                                                                                  │
# │   14                                                                                             │
# │   15 __version__ = "0.0.1-alpha"                                                                 │
# │   16                                                                                             │
# │ ❱ 17 from argilla_llama_index.llama_index_handler import ArgillaCallbackHandler                  │
# │   18                                                                                             │
# │   19 __all__ = ["ArgillaCallbackHandler"]                                                        │
# │   20                                                                                             │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/argilla │
# │ _llama_index/llama_index_handler.py:11 in <module>                                               │
# │                                                                                                  │
# │     8 from collections import defaultdict                                                        │
# │     9 from contextvars import ContextVar                                                         │
# │    10                                                                                            │
# │ ❱  11 from llama_index.callbacks.base_handler import BaseCallbackHandler                         │
# │    12 from llama_index.callbacks.schema import (                                                 │
# │    13 │   BASE_TRACE_EVENT,                                                                      │
# │    14 │   CBEventType,                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'llama_index.callbacks.base_handler'
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 set_global_handler("argilla", dataset_name="query_model")                                    │
# │   2                                                                                              │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/llama_i │
# │ ndex/core/callbacks/global_handlers.py:11 in set_global_handler                                  │
# │                                                                                                  │
# │     8 │   """Set global eval handlers."""                                                        │
# │     9 │   import llama_index.core                                                                │
# │    10 │                                                                                          │
# │ ❱  11 │   llama_index.core.global_handler = create_global_handler(eval_mode, **eval_params)      │
# │    12                                                                                            │
# │    13                                                                                            │
# │    14 def create_global_handler(eval_mode: str, **eval_params: Any) -> BaseCallbackHandler:      │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/llama_i │
# │ ndex/core/callbacks/global_handlers.py:97 in create_global_handler                               │
# │                                                                                                  │
# │    94 │   │   │   │   "ArgillaCallbackHandler is not installed. "                                │
# │    95 │   │   │   │   "Please install it using `pip install llama-index-callbacks-argilla`"      │
# │    96 │   │   │   )                                                                              │
# │ ❱  97 │   │   handler = argilla_callback_handler(**eval_params)                                  │
# │    98 │   else:                                                                                  │
# │    99 │   │   raise ValueError(f"Eval mode {eval_mode} not supported.")                          │
# │   100                                                                                            │
# │                                                                                                  │
# │ /Users/ignacio/Documents/recognai/argilla-llama-index/.venv/lib/python3.10/site-packages/llama_i │
# │ ndex/callbacks/argilla/base.py:11 in argilla_callback_handler                                    │
# │                                                                                                  │
# │    8 │   │   # lazy import                                                                       │
# │    9 │   │   from argilla_llama_index import ArgillaCallbackHandler                              │
# │   10 │   except ImportError:                                                                     │
# │ ❱ 11 │   │   raise ImportError("Please install Argilla with `pip install argilla`")              │
# │   12 │   return ArgillaCallbackHandler(**kwargs)                                                 │
# │   13                                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: Please install Argilla with `pip install argilla`

# %%
Settings.llm = OpenAI(model="gpt-3.5-turbo")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")
llm = Settings.llm

# %% [markdown]
# ## Building Multi-Document Agents

# %%
async def build_agent_per_doc(nodes, file_base):
    print(file_base)

    vi_out_path = f"./data/argilla_docs/{file_base}"
    summary_out_path = f"./data/argilla_docs/{file_base}_summary.pkl"
    if not os.path.exists(vi_out_path):
        Path("./data/argilla_docs/").mkdir(parents=True, exist_ok=True)
        # build vector index
        vector_index = VectorStoreIndex(nodes)
        vector_index.storage_context.persist(persist_dir=vi_out_path)
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=vi_out_path),
        )

    # build summary index
    summary_index = SummaryIndex(nodes)

    # define query engines
    vector_query_engine = vector_index.as_query_engine(llm=llm)
    summary_query_engine = summary_index.as_query_engine(
        response_mode="tree_summarize", llm=llm
    )

    # extract a summary
    if not os.path.exists(summary_out_path):
        Path(summary_out_path).parent.mkdir(parents=True, exist_ok=True)
        summary = str(
            await summary_query_engine.aquery(
                "Extract a concise 1-2 line summary of this document"
            )
        )
        pickle.dump(summary, open(summary_out_path, "wb"))
    else:
        summary = pickle.load(open(summary_out_path, "rb"))

    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name=f"vector_tool_{file_base}",
                description=f"Useful for questions related to specific facts",
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name=f"summary_tool_{file_base}",
                description=f"Useful for summarization questions",
            ),
        ),
    ]

    # build agent
    function_llm = OpenAI(model="gpt-4")
    agent = OpenAIAgent.from_tools(
        query_engine_tools,
        llm=function_llm,
        verbose=True,
        system_prompt=f"""\
You are a specialized agent designed to answer queries about the `{file_base}.html` part of the Argilla docs.
You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
""",
    )

    return agent, summary


async def build_agents(docs):
    node_parser = SentenceSplitter()

    # Build agents dictionary
    agents_dict = {}
    extra_info_dict = {}

    # # this is for the baseline
    # all_nodes = []

    for idx, doc in enumerate(tqdm(docs)):
        nodes = node_parser.get_nodes_from_documents([doc])
        # all_nodes.extend(nodes)

        # ID will be base + parent
        file_path = Path(doc.metadata["path"])
        file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)
        agent, summary = await build_agent_per_doc(nodes, file_base)

        agents_dict[file_base] = agent
        extra_info_dict[file_base] = {"summary": summary, "nodes": nodes}

    return agents_dict, extra_info_dict

# %%
agents_dict, extra_info_dict = await build_agents(docs)

# %% [markdown]
# ### Building a Document Agent for each document

# %% [markdown]
# ### Buildint a top-level agent

# %% [markdown]
# ## Running example queries

# %% [markdown]
# ## Visualizing in Argilla
